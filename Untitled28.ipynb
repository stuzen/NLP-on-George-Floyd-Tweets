# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/salih'

# %%
os.chdir('/Users/salih/Documents/pythonwork')

# %%
tweet=pd.read_csv("tweet_data5")

# %%
tweet.head()
# Out:
#    Unnamed: 0                      created_at                   id  \
# 0           0  Fri Jul 17 14:23:00 +0000 2020  1284131491622969344
# 1           1  Fri Jul 17 11:12:54 +0000 2020  1284083650682855429
# 2           2  Fri Jul 17 19:34:22 +0000 2020  1284209850105331712
# 3           3  Fri Jul 17 22:02:10 +0000 2020  1284247046288035840
# 4           4  Fri Jul 17 21:35:43 +0000 2020  1284240390938398726
#
#                 id_str                                          full_text  \
# 0  1284131491622969344  ‘It was like watching my husband get killed al...
# 1  1284083650682855429  Asking for evidence is racist now. \n\nMiss Sw...
# 2  1284209850105331712  Miss Swimsuit UK Stripped of Title For Posting...
# 3  1284247046288035840  George Floyd protests escalate in Portland as ...
# 4  1284240390938398726  Eric Garner should be alive today. Instead, si...
#
#    truncated display_text_range  \
# 0      False           [0, 208]
# 1      False           [0, 221]
# ...
